# %%
import pandas as pd
import numpy as np
import statistics as stat
import matplotlib.pyplot as plt
import seaborn as sn
import scipy.stats as stats

# %%
df=pd.read_csv(r'C:\Users\aaksh\OneDrive\Desktop\sales.csv')

# %%
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
stats.mode(df['Volume'])
# Out:
# ModeResult(mode=3, count=110)

# %%
stats.mode(df['Avg Price'])
# Out:
# ModeResult(mode=400, count=30)

# %%
stats.mode(df['Total Sales Value'])
# Out:
# ModeResult(mode=24300, count=14)

# %%
stats.mode(df['Discount Rate (%)'])
# Out:
# ModeResult(mode=5.007822189204133, count=1)

# %%
stats.mode(df['Discount Amount'])
# Out:
# ModeResult(mode=69.17794228822787, count=1)

# %%
stats.mode(df['Net Sales Value'])
# Out:
# ModeResult(mode=326.97480055470817, count=1)

# %%
plt.hist(df["Volume"], bins = 10, edgecolor= 'black')
plt.show()

# %%
plt.boxplot(x = 'Volume', data =df)
plt.xlabel('Volume')
plt.ylabel('Net Sales Value')
plt.savefig("Net_Sales_Value.png")
plt.show()

# %%
plt.hist(df["Avg Price"], bins = 20, edgecolor = 'y')
plt.show()

# %%
plt.boxplot(x = 'Avg Price', data= df)
plt.xlabel('Avg Price')
plt.ylabel('Total Sales Value')
plt.savefig("Total Sales Value.png")
plt.show()

# %%
plt.hist(df["Discount Rate (%)"], bins=20, edgecolor = 'red')
plt.show()

# %%
plt.boxplot(x= "Discount Rate (%)", data = df)
plt.xlabel('Discount Rate (%)')
plt.ylabel('Discount Amount')
plt.savefig("WeighInferences.png")
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.barh(df["Brand"], df["Model"])
plt.yticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.barh(df["Brand"], df["Avg Price"])
plt.yticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.barh(df["Brand"], df["Net Sales Value"])
plt.yticks(fontsize=14)
plt.show()

# %%
def expected_value(values, weights):
    values = np.asarray(values)
    weights = np.asarray(weights)
    return (values * weights).sum() / weights.sum()

# %%
c_count = [1,4,3,5,6,2]
ch_prob = [0.015,0.20,0.65,0.005,0.01,0.120]
expected_value(c_count, ch_prob)
# Out:
# 3.09
